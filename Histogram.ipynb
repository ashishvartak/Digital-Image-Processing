# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishvartak/Digital-Image-Processing/blob/main/Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing required libraries of opencv
import cv2


# importing library for plotting
from matplotlib import pyplot as plt

# reads an input image
img = cv2.imread('/content/drive/MyDrive/DIP/1/Ch3/croatia-02-small.tif',0)

# find frequency of pixels in range 0-255 i.e. one way to calculate histogram
histr = cv2.calcHist([img],[0],None,[256],[0,256])

# show the plotting graph of an image

plt.figure(figsize=(20,10))

plt.subplot(1,3,1)
plt.imshow(img,cmap='gray')

plt.subplot(1,3,2)
plt.plot(histr)

# another way to calculate histogram
plt.subplot(1,3,3)
plt.hist(img.ravel(),256,[0,256]);
